# %% [markdown]
# # Predictions for high-loop-density areas

# %% [markdown]
# Author: Amulya Garimella
#
# Last updated: 2025/05/02

# %% [markdown]
# ## Input files

# %%
input_cool_file = "/Users/amulyagarimella/Documents/2241finalproject/data/GM12878.GSE115524.Homo_Sapiens.CTCF.b1.mcool"

# %% [markdown]
# ## baseline: linear + logistic regression

# %%
import cooler
import numpy as np
from sklearn.linear_model import LogisticRegression, LinearRegression
import pybedtools
import pandas as pd

# %%
# We will divide the matrix into 64 sub-matrices

chrsizes = pd.read_csv("/Users/amulyagarimella/Documents/2241finalproject/HiC2MicroC/data/hg38.sizes", sep="\t", header=None, index_col=0)
input_res = 10000
CHRNAME = "chr1"
CHRLEN = chrsizes.loc[CHRNAME].values[0]

# %%
input_loops_file = f"/Users/amulyagarimella/Documents/2241finalproject/data/loops/GM12878.GSE115524.Homo_Sapiens.CTCF.b1.{input_res}.fithichip_hp.longrange.bed"

def process_loop_catalog_dataset(dataset_path):
    """
    Process the loop catalog dataset to extract relevant columns and convert them to a PyRanges object.
    """
    df = pd.read_csv(dataset_path, header=None, sep='\t')
    extra = df[3].str.split(r',|:|-', expand=True)
    df = pd.concat([df.drop(columns=[3]), extra], axis=1)
    df.columns = ["chr_1", "start_1", "end_1", "chr_2", "start_2", "end_2", "score"]
    # Convert start and end columns to integers
    df[["start_1", "end_1", "start_2", "end_2"]] = df[["start_1", "end_1", "start_2", "end_2"]].astype(int)
    
    # Convert score to float
    df["score"] = df["score"].astype(float)
    return df

loops = process_loop_catalog_dataset(input_loops_file)

# %%
# extract part of cooler
clr = cooler.Cooler(f'{input_cool_file}::/resolutions/{input_res}')
start, size = 0, min(input_res*100, CHRLEN)
#mat = clr.matrix(balance=False)[start:start+size, start:start+size]

# %%
chrlen_bins = CHRLEN//input_res
min_submatrices = 100
submatrix_len = 100*input_res
submatrix_len_bins = submatrix_len//input_res

overlap_len = max((submatrix_len_bins*min_submatrices - chrlen_bins) // (min_submatrices - 1),0)
stridelen_bins = submatrix_len_bins - overlap_len

# %%
CHRLEN
# Out:
# np.int64(248956422)

# %%
# Feature extraction: divide mat into submatrices
# Labels: determine number of loops in each submatrix
features = []
labels = []


for i in np.arange(0, chrlen_bins, stridelen_bins):
    # Extract the submatrix
    i_end = min(i + submatrix_len_bins, chrlen_bins)
    #print(f"Bin {i} to {i_end}")
    
    start_coord = int(i*input_res)
    end_coord = int(i_end*input_res)
    #print(f"Start coord: {start_coord}, End coord: {end_coord}")

    counts = clr.pixels()[i:i_end]
 
    
    submat = counts["count"].values 
    
    # Create feature vector from the submatrix
    if len(submat) < submatrix_len_bins:
        # Pad the submatrix with zeros
        submat = np.pad(submat, (0, submatrix_len_bins - len(submat)), 'constant')
        print(f"Submatrix {i} padded to {submatrix_len_bins} bins")

    features.append(submat)
    # Determine the number of loops in the submatrix
    # print(loops.head())
    loops_in_submat = loops.loc[
        (loops['chr_1'] == CHRNAME) & 
        (loops['start_1'] >= start_coord) & 
        (loops['end_1'] <= end_coord) & 
        (loops['chr_2'] == CHRNAME) & 
        (loops['start_2'] >= start_coord) & 
        (loops['end_2'] <= end_coord)
    ]

    labels.append(len(loops_in_submat))
    if len(loops_in_submat) > 0:
        print(f"Submatrix {i} has {len(loops_in_submat)} loops")
    else:
        print(f"Submatrix {i} has no loops")


# Convert to numpy arrays
features = np.array(features)
print(f"Created {len(features)} submatrices")
print(f"Feature shape: {features.shape}")

# Convert labels to numpy array
labels = np.array(labels)
print(f"Labels shape: {labels.shape}")
# Out:
# Submatrix 0 has 8 loops
# Submatrix 100 has 76 loops
# Submatrix 200 has 62 loops
# Submatrix 300 has 20 loops
# Submatrix 400 has 2 loops
# Submatrix 500 has 12 loops
# Submatrix 600 has 42 loops
# Submatrix 700 has 14 loops
# Submatrix 800 has 38 loops
# Submatrix 900 has 64 loops
# Submatrix 1000 has 70 loops
# Submatrix 1100 has 48 loops
# Submatrix 1200 has 72 loops
# Submatrix 1300 has 12 loops
# Submatrix 1400 has 14 loops
# Submatrix 1500 has 46 loops
# Submatrix 1600 has 50 loops
# Submatrix 1700 has 50 loops
# Submatrix 1800 has 10 loops
# Submatrix 1900 has 66 loops
# Submatrix 2000 has 18 loops
# Submatrix 2100 has 42 loops
# Submatrix 2200 has 20 loops
# Submatrix 2300 has 60 loops
# Submatrix 2400 has 52 loops
# Submatrix 2500 has no loops
# Submatrix 2600 has no loops
# Submatrix 2700 has no loops
# Submatrix 2800 has no loops
# Submatrix 2900 has no loops
# Submatrix 3000 has no loops
# Submatrix 3100 has no loops
# Submatrix 3200 has no loops
# Submatrix 3300 has no loops
# Submatrix 3400 has no loops
# Submatrix 3500 has no loops
# Submatrix 3600 has no loops
# Submatrix 3700 has no loops
# Submatrix 3800 has no loops
# Submatrix 3900 has no loops
# Submatrix 4000 has no loops
# Submatrix 4100 has no loops
# Submatrix 4200 has no loops
# Submatrix 4300 has no loops
# Submatrix 4400 has no loops
# Submatrix 4500 has no loops
# Submatrix 4600 has no loops
# Submatrix 4700 has no loops
# Submatrix 4800 has no loops
# Submatrix 4900 has no loops
# Submatrix 5000 has no loops
# Submatrix 5100 has no loops
# Submatrix 5200 has no loops
# Submatrix 5300 has no loops
# Submatrix 5400 has no loops
# Submatrix 5500 has no loops
# Submatrix 5600 has no loops
# Submatrix 5700 has no loops
# Submatrix 5800 has no loops
# Submatrix 5900 has no loops
# Submatrix 6000 has no loops
# Submatrix 6100 has no loops
# Submatrix 6200 has no loops
# Submatrix 6300 has no loops
# Submatrix 6400 has no loops
# Submatrix 6500 has no loops
# Submatrix 6600 has no loops
# Submatrix 6700 has no loops
# Submatrix 6800 has no loops
# Submatrix 6900 has no loops
# Submatrix 7000 has no loops
# Submatrix 7100 has no loops
# Submatrix 7200 has no loops
# Submatrix 7300 has no loops
# Submatrix 7400 has no loops
# Submatrix 7500 has no loops
# Submatrix 7600 has no loops
# Submatrix 7700 has no loops
# Submatrix 7800 has no loops
# Submatrix 7900 has no loops
# Submatrix 8000 has no loops
# Submatrix 8100 has no loops
# Submatrix 8200 has no loops
# Submatrix 8300 has no loops
# Submatrix 8400 has no loops
# Submatrix 8500 has no loops
# Submatrix 8600 has no loops
# Submatrix 8700 has no loops
# Submatrix 8800 has no loops
# Submatrix 8900 has no loops
# Submatrix 9000 has no loops
# Submatrix 9100 has no loops
# Submatrix 9200 has no loops
# Submatrix 9300 has no loops
# Submatrix 9400 has no loops
# Submatrix 9500 has no loops
# Submatrix 9600 has no loops
# Submatrix 9700 has no loops
# Submatrix 9800 has no loops
# Submatrix 9900 has no loops
# Submatrix 10000 has no loops
# Submatrix 10100 has no loops
# Submatrix 10200 has no loops
# Submatrix 10300 has no loops
# Submatrix 10400 has no loops
# Submatrix 10500 has no loops
# Submatrix 10600 has no loops
# Submatrix 10700 has no loops
# Submatrix 10800 has no loops
# Submatrix 10900 has no loops
# Submatrix 11000 has no loops
# Submatrix 11100 has no loops
# Submatrix 11200 has no loops
# Submatrix 11300 has no loops
# Submatrix 11400 has no loops
# Submatrix 11500 has no loops
# Submatrix 11600 has no loops
# Submatrix 11700 has no loops
# Submatrix 11800 has no loops
# Submatrix 11900 has no loops
# Submatrix 12000 has no loops
# Submatrix 12100 has no loops
# Submatrix 12200 has no loops
# Submatrix 12300 has no loops
# Submatrix 12400 has no loops
# Submatrix 12500 has no loops
# Submatrix 12600 has no loops
# Submatrix 12700 has no loops
# Submatrix 12800 has no loops
# Submatrix 12900 has no loops
# Submatrix 13000 has no loops
# Submatrix 13100 has no loops
# Submatrix 13200 has no loops
# Submatrix 13300 has no loops
# Submatrix 13400 has no loops
# Submatrix 13500 has no loops
# Submatrix 13600 has no loops
# Submatrix 13700 has no loops
# Submatrix 13800 has no loops
# Submatrix 13900 has no loops
# Submatrix 14000 has no loops
# Submatrix 14100 has no loops
# Submatrix 14200 has no loops
# Submatrix 14300 has no loops
# Submatrix 14400 has no loops
# Submatrix 14500 has no loops
# Submatrix 14600 has no loops
# Submatrix 14700 has no loops
# Submatrix 14800 has no loops
# Submatrix 14900 has no loops
# Submatrix 15000 has no loops
# Submatrix 15100 has no loops
# Submatrix 15200 has no loops
# Submatrix 15300 has no loops
# Submatrix 15400 has no loops
# Submatrix 15500 has no loops
# Submatrix 15600 has no loops
# Submatrix 15700 has no loops
# Submatrix 15800 has no loops
# Submatrix 15900 has no loops
# Submatrix 16000 has no loops
# Submatrix 16100 has no loops
# Submatrix 16200 has no loops
# Submatrix 16300 has no loops
# Submatrix 16400 has no loops
# Submatrix 16500 has no loops
# Submatrix 16600 has no loops
# Submatrix 16700 has no loops
# Submatrix 16800 has no loops
# Submatrix 16900 has no loops
# Submatrix 17000 has no loops
# Submatrix 17100 has no loops
# Submatrix 17200 has no loops
# Submatrix 17300 has no loops
# Submatrix 17400 has no loops
# Submatrix 17500 has no loops
# Submatrix 17600 has no loops
# Submatrix 17700 has no loops
# Submatrix 17800 has no loops
# Submatrix 17900 has no loops
# Submatrix 18000 has no loops
# Submatrix 18100 has no loops
# Submatrix 18200 has no loops
# Submatrix 18300 has no loops
# Submatrix 18400 has no loops
# Submatrix 18500 has no loops
# Submatrix 18600 has no loops
# Submatrix 18700 has no loops
# Submatrix 18800 has no loops
# Submatrix 18900 has no loops
# Submatrix 19000 has no loops
# Submatrix 19100 has no loops
# Submatrix 19200 has no loops
# Submatrix 19300 has no loops
# Submatrix 19400 has no loops
# Submatrix 19500 has no loops
# Submatrix 19600 has no loops
# Submatrix 19700 has no loops
# Submatrix 19800 has no loops
# Submatrix 19900 has no loops
# Submatrix 20000 has no loops
# Submatrix 20100 has no loops
# Submatrix 20200 has no loops
# Submatrix 20300 has no loops
# Submatrix 20400 has no loops
# Submatrix 20500 has no loops
# Submatrix 20600 has no loops
# Submatrix 20700 has no loops
# Submatrix 20800 has no loops
# Submatrix 20900 has no loops
# Submatrix 21000 has no loops
# Submatrix 21100 has no loops
# Submatrix 21200 has no loops
# Submatrix 21300 has no loops
# Submatrix 21400 has no loops
# Submatrix 21500 has no loops
# Submatrix 21600 has no loops
# Submatrix 21700 has no loops
# Submatrix 21800 has no loops
# Submatrix 21900 has no loops
# Submatrix 22000 has no loops
# Submatrix 22100 has no loops
# Submatrix 22200 has no loops
# Submatrix 22300 has no loops
# Submatrix 22400 has no loops
# Submatrix 22500 has no loops
# Submatrix 22600 has no loops
# Submatrix 22700 has no loops
# Submatrix 22800 has no loops
# Submatrix 22900 has no loops
# Submatrix 23000 has no loops
# Submatrix 23100 has no loops
# Submatrix 23200 has no loops
# Submatrix 23300 has no loops
# Submatrix 23400 has no loops
# Submatrix 23500 has no loops
# Submatrix 23600 has no loops
# Submatrix 23700 has no loops
# Submatrix 23800 has no loops
# Submatrix 23900 has no loops
# Submatrix 24000 has no loops
# Submatrix 24100 has no loops
# Submatrix 24200 has no loops
# Submatrix 24300 has no loops
# Submatrix 24400 has no loops
# Submatrix 24500 has no loops
# Submatrix 24600 has no loops
# Submatrix 24700 has no loops
# Submatrix 24800 padded to 100 bins
# Submatrix 24800 has no loops
# Created 249 submatrices
# Feature shape: (249, 100)
# Labels shape: (249,)

# %%
# Train a linear regression model

linreg = LinearRegression()
linreg.fit(features, labels)
# Out:
# LinearRegression()

# %%
linreg
# Out:
# LinearRegression()

# %% [markdown]
# ## baseline 2: single layer CNN

# %%
import torch
import torch.nn as nn
import cooler

# %%
# load sparse mat
clr = cooler.Cooler('input.cool::/resolutions/10000')
mat = clr.matrix(balance=True)[i0:i0+3, i0:i0+3]
x = torch.tensor(mat, dtype=torch.float32)[None,None]

class LiteLoopNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.dw = nn.Conv2d(1,1,3,padding=1,groups=1)  # depthwise on 1 channel
        self.pw = nn.Conv2d(1,1,1)                     # pointwise
        self.pool = nn.AdaptiveAvgPool2d(1)
        # self.dropout = nn.Dropout(p=0.5)               # added dropout layer
    def forward(self, x):
        x = nn.functional.relu(self.pw(self.dw(x)))
        return torch.sigmoid(self.pool(x).view(-1))

model = LiteLoopNet()
out = model(x)

# %% [markdown]
# ## GNN

# %%
import cooler
import torch
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GCNConv
# Out:
# /Users/amulyagarimella/documents/2241finalproject/predictions_venv/lib/python3.11/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: dlopen(/Users/amulyagarimella/documents/2241finalproject/predictions_venv/lib/python3.11/site-packages/libpyg.so, 0x0006): Library not loaded: /Library/Frameworks/Python.framework/Versions/3.11/Python
#   Referenced from: <9BBB4F05-41BA-385E-B2A3-76313944D73A> /Users/amulyagarimella/Documents/2241finalproject/predictions_venv/lib/python3.11/site-packages/libpyg.so
#   Reason: tried: '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file)
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /Users/amulyagarimella/documents/2241finalproject/predictions_venv/lib/python3.11/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: dlopen(/Users/amulyagarimella/documents/2241finalproject/predictions_venv/lib/python3.11/site-packages/libpyg.so, 0x0006): Library not loaded: /Library/Frameworks/Python.framework/Versions/3.11/Python
#   Referenced from: <9BBB4F05-41BA-385E-B2A3-76313944D73A> /Users/amulyagarimella/Documents/2241finalproject/predictions_venv/lib/python3.11/site-packages/libpyg.so
#   Reason: tried: '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file)
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
# 1. load cooler pixels for region
clr = cooler.Cooler('input.cool::/resolutions/10000')
pixels = clr.pixels().fetch('chr1')
mask = (pixels['bin1_id'].between(i0,i1) &
        pixels['bin2_id'].between(i0,i1))
sub = pixels[mask]

# 2. build graph edges + node features
edge_index = torch.tensor([
    sub['bin1_id'].values - i0,
    sub['bin2_id'].values - i0
], dtype=torch.long)
x = torch.tensor(sub['count'].values, dtype=torch.float32).unsqueeze(1)
data = Data(x=x, edge_index=edge_index)

# 3. GCN definition
class LoopGNN(torch.nn.Module):
    def __init__(self, in_ch, hid_ch):
        super().__init__()
        self.conv1 = GCNConv(in_ch, hid_ch)
        self.conv2 = GCNConv(hid_ch, 1)
    def forward(self, d):
        h = torch.relu(self.conv1(d.x, d.edge_index))
        return self.conv2(h, d.edge_index)

model = LoopGNN(1,16).to('cuda')
opt   = torch.optim.Adam(model.parameters(), lr=1e-3)
crit  = torch.nn.BCEWithLogitsLoss()

# 4. training
loader = DataLoader([data], batch_size=1)
for batch in loader:
    batch = batch.to('cuda')
    opt.zero_grad()
    out = model(batch).mean()            # graph-level score :contentReference[oaicite:7]{index=7}
    loss = crit(out, torch.tensor([1.],device='cuda'))
    loss.backward()
    opt.step()

# %% [markdown]
# ## gzipped data
