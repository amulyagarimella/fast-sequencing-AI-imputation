# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
os.chdir("/Users/amulyagarimella/Documents/2241finalproject/HiCNN2_package/")

# %% [markdown]
# ## example data

# %%
prediction = np.load("data/chr15.predictedMat.npy")

# %%
prediction_submats = np.load("data/chr15.subMats_HiCNN23_16.npy")

# %%
prediction_submats.shape
# Out:
# (2892, 1, 28, 28)

# %%
start = 2400
size = 400
end = start + size
plt.matshow(prediction[start:end, start:end], vmax=50)

# %%
index = np.load("/Users/amulyagarimella/Documents/2241finalproject/HiCNN2_package/data/chr15.index.npy")

# %%
orig_index = np.load("/Users/amulyagarimella/Documents/2241finalproject/HiCNN2_package/data/chr15.orig.index.npy")

# %%
orig_matrix = np.load("/Users/amulyagarimella/Documents/2241finalproject/HiCNN2_package/data/chr15.origMat.npy")
orig_matrix_submat = np.load("/Users/amulyagarimella/Documents/2241finalproject/HiCNN2_package/data/chr15.subMats.npy")

# %%
start = 0
size = 2000
end = start + size

disp_limit = 20
for i in range(0, np.shape(orig_matrix_submat)[0]):
    if np.max(orig_matrix_submat[i]) > 20:
        plt.matshow(np.squeeze(orig_matrix_submat[i]))
        plt.colorbar()
        plt.show()
        disp_limit -= 1
        if disp_limit == 0:
            break

# %% [markdown]
# ## chr21 data

# %%
start = 2900
size = 100
end = start + size

# %%
prediction_full = np.load("/Users/amulyagarimella/Documents/2241finalproject/outputs/imputed/HiCNN2/full/2025-05-05_20-05-06/21_predicted_hic.npy")

# %%
plt.matshow(prediction_full[start:start+size, start:start+size], vmax=25)
plt.colorbar()

# %% [markdown]
# ## roi

# %% [markdown]
# ### random selection of ROI - proof of concept

# %%
prediction_roi_random = np.load("/Users/amulyagarimella/Documents/2241finalproject/outputs/imputed/HiCNN2/roi/2025-05-05_17-12-25/21_predicted_hic.npy")

# %%
plt.matshow(prediction_roi_random[start:start+size, start:start+size], vmax=25)
plt.colorbar()

# %% [markdown]
# ### ridge model

# %%
prediction_roi_ridge = np.load("/Users/amulyagarimella/Documents/2241finalproject/outputs/imputed/HiCNN2/roi/2025-05-05_18-48-57/21_predicted_hic.npy")

# %%
plt.matshow(prediction_roi_ridge[start:start+size, start:start+size], vmax=25)
plt.colorbar()

# %% [markdown]
# ### ridge w/ imputation

# %%
prediction_roi_ridge_imputed_expected = np.load("/Users/amulyagarimella/Documents/2241finalproject/outputs/imputed/HiCNN2/roi/2025-05-06_08-06-32/21_predicted_hic.npy")

# %%
prediction_roi_ridge_imputed_lowres = np.load("/Users/amulyagarimella/Documents/2241finalproject/outputs/imputed/HiCNN2/roi/2025-05-06_08-04-00/21_predicted_hic.npy")

# %%
plt.matshow(prediction_roi_ridge_imputed_lowres[start:start+size, start:start+size], vmax=50)
plt.colorbar()

# %%
plt.matshow(prediction_roi_ridge_imputed_expected[start:start+size, start:start+size], vmax=50)
plt.colorbar()
